# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as ply

# %%
bad=pd.read_csv('breaking_bad.csv',encoding='latin-1')
bad
# Out:
#          Date  Season  Episode                          Title  \
# 0   20-Jan-08       1        1                          Pilot
# 1   27-Jan-08       1        2            Cat's in the Bag...
# 2   10-Feb-08       1        3  ...And the Bag's in the River
# 3   17-Feb-08       1        4                     Cancer Man
# 4   24-Feb-08       1        5                    Gray Matter
# ..        ...     ...      ...                            ...
# 57  01-Sep-13       5       12                      Rabid Dog
# 58  08-Sep-13       5       13                    To'hajiilee
# 59  15-Sep-13       5       14                     Ozymandias
# 60  22-Sep-13       5       15                  Granite State
# 61  29-Sep-13       5       16                         Felina
#
#           Directed by                            Written by  Duration_mins  \
# 0      Vince Gilligan                        Vince Gilligan             58
# ...

# %%
bad.head()
# Out:
#         Date  Season  Episode                          Title     Directed by  \
# 0  20-Jan-08       1        1                          Pilot  Vince Gilligan
# 1  27-Jan-08       1        2            Cat's in the Bag...  Adam Bernstein
# 2  10-Feb-08       1        3  ...And the Bag's in the River  Adam Bernstein
# 3  17-Feb-08       1        4                     Cancer Man       Jim McKay
# 4  24-Feb-08       1        5                    Gray Matter    Tricia Brock
#
#                   Written by  Duration_mins  \
# 0             Vince Gilligan             58
# 1             Vince Gilligan             48
# 2             Vince Gilligan             48
# 3             Vince Gilligan             48
# 4  Vince Gilligan, Patty Lin             48
#
#                                              Summary  Rating_IMDB  \
# 0  Diagnosed with terminal lung cancer, chemistry...          9.1
# 1  After their first drug deal goes terribly wron...          8.7
# ...

# %%
bad.tail()
# Out:
#          Date  Season  Episode          Title        Directed by  \
# 57  01-Sep-13       5       12      Rabid Dog         Sam Catlin
# 58  08-Sep-13       5       13    To'hajiilee  Michelle MacLaren
# 59  15-Sep-13       5       14     Ozymandias       Rian Johnson
# 60  22-Sep-13       5       15  Granite State        Peter Gould
# 61  29-Sep-13       5       16         Felina     Vince Gilligan
#
#                               Written by  Duration_mins  \
# 57            Vince Gilligan, Sam Catlin             48
# 58        Vince Gilligan, George Mastras             47
# 59  Vince Gilligan, Moira Walley-Beckett             48
# 60           Vince Gilligan, Peter Gould             55
# 61                        Vince Gilligan             55
#
#                                               Summary  Rating_IMDB  \
# 57  Walt discovers Jesse broke into his house and ...          9.2
# 58  Jesse and Hank come up with an idea to take Wa...          9.8
# ...

# %%
bad.info
# Out:
# <bound method DataFrame.info of          Date  Season  Episode                          Title  \
# 0   20-Jan-08       1        1                          Pilot
# 1   27-Jan-08       1        2            Cat's in the Bag...
# 2   10-Feb-08       1        3  ...And the Bag's in the River
# 3   17-Feb-08       1        4                     Cancer Man
# 4   24-Feb-08       1        5                    Gray Matter
# ..        ...     ...      ...                            ...
# 57  01-Sep-13       5       12                      Rabid Dog
# 58  08-Sep-13       5       13                    To'hajiilee
# 59  15-Sep-13       5       14                     Ozymandias
# 60  22-Sep-13       5       15                  Granite State
# 61  29-Sep-13       5       16                         Felina
#
#           Directed by                            Written by  Duration_mins  \
# 0      Vince Gilligan                        Vince Gilligan             58
# ...

# %%
# Total null values is 5 in (U.S. viewers_million)
bad.isnull().sum()
# Out:
# Date                    0
# Season                  0
# Episode                 0
# Title                   0
# Directed by             0
# Written by              0
# Duration_mins           0
# Summary                 0
# Rating_IMDB             0
# U.S. viewers_million    5
# dtype: int64

# %%
# dropped nan values and filled it with value 0
bad=bad.dropna()
bad=bad.fillna(0)

# %%
bad.isnull().sum()
# Out:
# Date                    0
# Season                  0
# Episode                 0
# Title                   0
# Directed by             0
# Written by              0
# Duration_mins           0
# Summary                 0
# Rating_IMDB             0
# U.S. viewers_million    0
# dtype: int64

# %%
#62 rows and 10 column
bad.shape
# Out:
# (57, 10)

# %%
#total cells
bad.size
# Out:
# 570

# %%
bad.value_counts
# Out:
# <bound method DataFrame.value_counts of          Date  Season  Episode                          Title  \
# 0   20-Jan-08       1        1                          Pilot
# 1   27-Jan-08       1        2            Cat's in the Bag...
# 2   10-Feb-08       1        3  ...And the Bag's in the River
# 3   17-Feb-08       1        4                     Cancer Man
# 4   24-Feb-08       1        5                    Gray Matter
# 5   02-Mar-08       1        6       Crazy Handful of Nothin'
# 6   09-Mar-08       1        7     A No-Rough-Stuff-Type Deal
# 7   08-Mar-09       2        1             Seven Thirty-Seven
# 8   15-Mar-09       2        2                        Grilled
# 9   22-Mar-09       2        3              Bit by a Dead Bee
# 10  29-Mar-09       2        4                           Down
# 11  05-Apr-09       2        5                       Breakage
# 12  12-Apr-09       2        6                       Peekaboo
# ...

# %%
bad.describe()
# Out:
#           Season    Episode  Duration_mins  Rating_IMDB  U.S. viewers_million
# count  57.000000  57.000000      57.000000    57.000000             57.000000
# mean    3.403509   6.807018      48.000000     9.029825              2.324386
# std     1.360930   4.133654       2.732084     0.527448              1.719224
# min     1.000000   1.000000      43.000000     7.800000              0.970000
# 25%     2.000000   3.000000      47.000000     8.700000              1.460000
# 50%     4.000000   6.000000      47.000000     8.900000              1.710000
# 75%     5.000000  10.000000      48.000000     9.500000              2.290000
# max     5.000000  16.000000      60.000000    10.000000             10.280000

# %%
bad['Season'].value_counts().sum()
# Out:
# 57

# %%
bad[['Season','Duration_mins']].sum()
# Out:
# Season            194
# Duration_mins    2736
# dtype: int64

# %%
season_episode=bad.groupby('Season')['Episode'].count()
season_episode
# Out:
# Season
# 1     7
# 2     8
# 3    13
# 4    13
# 5    16
# Name: Episode, dtype: int64

# %%
pd.set_option("display.max_rows",100)

# %%
#all ratings of each season is shown below
season_rating=bad.groupby('Season')[['Episode','Rating_IMDB']].value_counts()
season_rating
# Out:
# Season  Episode  Rating_IMDB
# 1       1        9.1            1
#         2        8.7            1
#         3        8.8            1
#         4        8.3            1
#         5        8.4            1
#         6        9.3            1
#         7        8.9            1
# 2       1        8.7            1
#         2        9.3            1
#         3        8.4            1
#         4        8.3            1
#         5        8.4            1
#         6        8.9            1
#         8        9.2            1
#         13       9.3            1
# 3       13       9.7            1
#         1        8.6            1
#         2        8.7            1
#         3        8.5            1
#         4        8.3            1
#         5        8.7            1
#         6        9.3            1
#         7        9.6            1
#         8        8.8            1
#         9        8.5            1
#         10       7.8            1
# ...

# %%
# each seasons highest ratings are shown below
bad.groupby('Season')['Rating_IMDB'].max()
# Out:
# Season
# 1     9.3
# 2     9.3
# 3     9.7
# 4     9.9
# 5    10.0
# Name: Rating_IMDB, dtype: float64

# %%
# Each seasons lowest rating is shown below
bad.groupby('Season')['Rating_IMDB'].min()
# Out:
# Season
# 1    8.3
# 2    8.3
# 3    7.8
# 4    8.1
# 5    8.9
# Name: Rating_IMDB, dtype: float64

# %%
# each seasons duration by minutes is shown below
bad.groupby('Season')['Duration_mins'].sum()
# Out:
# Season
# 1    346
# 2    376
# 3    611
# 4    627
# 5    776
# Name: Duration_mins, dtype: int64

# %%
bad.columns
# Out:
# Index(['Date', 'Season', 'Episode', 'Title', 'Directed by', 'Written by',
#        'Duration_mins', 'Summary', 'Rating_IMDB', 'U.S. viewers_million'],
#       dtype='object')

# %%
bad.groupby('Episode')[['U.S. viewers_million']].value_counts()
# Out:
# Episode  U.S. viewers_million
# 1        1.41                    1
#          1.66                    1
#          1.95                    1
#          2.58                    1
#          2.93                    1
# 2        1.49                    1
#          1.55                    1
#          1.60                    1
#          1.97                    1
#          2.29                    1
# 3        1.08                    1
#          1.13                    1
#          1.33                    1
#          1.71                    1
#          2.20                    1
# 4        1.09                    1
#          1.29                    1
#          1.46                    1
#          1.83                    1
#          2.29                    1
# 5        0.97                    1
#          1.21                    1
#          1.61                    1
#          1.75                    1
#          2.48                    1
# 6        2.81                    1
# ...

# %%
plt.scatter(bad['Season'],bad['Rating_IMDB'])
plt.title('Rating By Season')
plt.xlabel('Season')
plt.ylabel('IMDB Rating')
plt.show()

# %%
# Histogram of episode rating using matplotlib
plt.hist(bad['Rating_IMDB'],bins=15,color='skyblue',edgecolor='black')
plt.title('Distribution of Episode Rating')
plt.xlabel('Rating')
plt.ylabel('Episode')
plt.show()

# Box plot of episode ratings using Seaborn
sns.boxplot(x='Season',y='Episode',data=bad)
plt.title('Boxplot of episode rating by season')
plt.show()

# %%
# bad['Total_minutes']=bad['Duration_mins']*bad['Episode']
# bad

# %%
bad
# Out:
#          Date  Season  Episode                          Title  \
# 0   20-Jan-08       1        1                          Pilot
# 1   27-Jan-08       1        2            Cat's in the Bag...
# 2   10-Feb-08       1        3  ...And the Bag's in the River
# 3   17-Feb-08       1        4                     Cancer Man
# 4   24-Feb-08       1        5                    Gray Matter
# 5   02-Mar-08       1        6       Crazy Handful of Nothin'
# 6   09-Mar-08       1        7     A No-Rough-Stuff-Type Deal
# 7   08-Mar-09       2        1             Seven Thirty-Seven
# 8   15-Mar-09       2        2                        Grilled
# 9   22-Mar-09       2        3              Bit by a Dead Bee
# 10  29-Mar-09       2        4                           Down
# 11  05-Apr-09       2        5                       Breakage
# 12  12-Apr-09       2        6                       Peekaboo
# 14  26-Apr-09       2        8               Better Call Saul
# ...

# %%
season_counts = bad['Season'].value_counts()

# Create a bar diagram
plt.bar(season_counts.index, season_counts.values, color='skyblue')
plt.title('Number of Episodes in Each Season of Breaking Bad')
plt.xlabel('Season')
plt.ylabel('Number of Episodes')
plt.show()

# %%
sns.countplot(x='Rating_IMDB', data=bad)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=bad,x='U.S. viewers_million')
plt.title('Total No.of Viewers')
plt.xlabel('Viewers')
plt.ylabel('Count of viewes')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=bad,x='Duration_mins')
plt.title('Duration')
plt.xlabel('Duration')
plt.ylabel('Count of viewes')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()
